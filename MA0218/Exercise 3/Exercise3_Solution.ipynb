# %% [markdown]
# ## Exercise 3

# %% [markdown]
# ### Problem 1 : Analysis of Numeric Variables
# Extract the following Numeric variables from the dataset, and store as a new Pandas DataFrame.
# houseNumData = pd.DataFrame(houseData[['LotArea', 'GrLivArea', 'TotalBsmtSF', 'GarageArea', 'SalePrice']])
#
#     a) Check the individual statistical description and visualize the statistical distributions of each of these variables.
#     b) Comment if the distributions look like “Normal Distribution”, or different. Use the .skew() method to find the
#     “skewness” of each of the five distributions. Which of the variables has the maximum number of outliers?
#     c) Check the relationship amongst the variables using mutual correlation and the correlation heatmap. Comment
#     which of the variables has the strongest correlation with “SalePrice”. Is this useful in predicting “SalePrice”?
#     d) Check the relationship amongst the variables using mutual jointplots and an overall pairplot. Comment which of
#     the variables has the strongest linear relation with “SalePrice”. Is this useful in predicting “SalePrice”?

# %% [markdown]
# #### Import all the needed libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# #### a) Check the individual statistical description and visualize the statistical distributions of each of these variables.

# %%
houseData = pd.read_csv('train.csv')
display(houseData.head(10))
display(houseData.sample(10))
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 485    486          20       RL         80.0     9600   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 85      86          60       RL        121.0    16059   Pave   NaN      Reg
# 1096  1097          70       RM         60.0     6882   Pave   NaN      Reg
# 70      71          20       RL         95.0    13651   Pave   NaN      IR1
# 317    318          60       FV         75.0     9000   Pave   NaN      Reg
# 812    813          20  C (all)         66.0     8712   Grvl   NaN      Reg
# 651    652          70       RL         60.0     9084   Pave   NaN      Reg
# 555    556          45       RM         58.0     6380   Pave   NaN      Reg
# 593    594         120       RM          NaN     4435   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 485          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 304          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 85           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1096         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 70           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 317          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 812          Bnk    AllPub  ...        0    NaN    NaN        Shed      54
# 651          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 555          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 593          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 485       7   2009        WD         Normal     147000
# 304       5   2008        WD         Normal     295000
# 85        4   2006        WD         Normal     260000
# 1096      3   2007        WD         Normal     127000
# 70        2   2007        WD         Normal     244000
# 317      12   2007        WD         Normal     270000
# 812       6   2010        WD         Alloca      55993
# 651      10   2009        WD         Normal     108000
# 555       8   2006        WD         Normal     113000
# 593       5   2009        WD         Normal     140000
#
# [10 rows x 81 columns]

# %%
houseNumData = pd.DataFrame(houseData[['LotArea', 'GrLivArea', 'TotalBsmtSF', 'GarageArea', 'SalePrice']])  
display(houseNumData.head(10))
display(houseNumData.sample(10))
# Out:
#    LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# 0     8450       1710          856         548     208500
# 1     9600       1262         1262         460     181500
# 2    11250       1786          920         608     223500
# 3     9550       1717          756         642     140000
# 4    14260       2198         1145         836     250000
# 5    14115       1362          796         480     143000
# 6    10084       1694         1686         636     307000
# 7    10382       2090         1107         484     200000
# 8     6120       1774          952         468     129900
# 9     7420       1077          991         205     118000
#       LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# 164      5400       1616         1149         216     152000
# 548      8235        825          825         720     125000
# 988     12046       2030          848         551     195000
# 1136     9600       1252         1032         288     119000
# 126      4928        958         1078         440     128000
# 1248     9600       2058          735         396     129500
# 869      9938       1949         1050         574     236000
# 966      9600       1308          728         256     160000
# 302     13704       1541         1541         843     205000
# 1039     1477        630          630         286      80000

# %% [markdown]
# ##### KDE Plot

# %%
f, axes = plt.subplots(5, 1, figsize=(36, 24))
sb.kdeplot(data = houseNumData['LotArea'], ax = axes[0])
sb.kdeplot(data = houseNumData['GrLivArea'], ax = axes[1])
sb.kdeplot(data = houseNumData['TotalBsmtSF'], ax = axes[2])
sb.kdeplot(data = houseNumData['GarageArea'], ax = axes[3])
sb.kdeplot(data = houseNumData['SalePrice'], ax = axes[4])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# ##### BOX Plot

# %%
f, axes = plt.subplots(5, 1, figsize = (12,24))
sb.boxplot(data = houseNumData['LotArea'], orient = "h", ax = axes[0])
sb.boxplot(data = houseNumData['GrLivArea'], orient = "h", ax = axes[1])
sb.boxplot(data = houseNumData['TotalBsmtSF'], orient = "h", ax = axes[2])
sb.boxplot(data = houseNumData['GarageArea'], orient = "h", ax = axes[3])
sb.boxplot(data = houseNumData['SalePrice'], orient = "h", ax = axes[4])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Histogram Plot

# %%
f, axes = plt.subplots(5, 1, figsize = (12,24))
sb.histplot(data = houseNumData['LotArea'], ax = axes[0])
sb.histplot(data = houseNumData['GrLivArea'], ax = axes[1])
sb.histplot(data = houseNumData['TotalBsmtSF'], ax = axes[2])
sb.histplot(data = houseNumData['GarageArea'], ax = axes[3])
sb.histplot(data = houseNumData['SalePrice'], ax = axes[4])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ##### Violin Plot

# %%
f, axes = plt.subplots(5, 1, figsize = (12,24))
sb.violinplot(data = houseNumData['LotArea'], orient = "h", ax = axes[0])
sb.violinplot(data = houseNumData['GrLivArea'], orient = "h", ax = axes[1])
sb.violinplot(data = houseNumData['TotalBsmtSF'], orient = "h", ax = axes[2])
sb.violinplot(data = houseNumData['GarageArea'], orient = "h", ax = axes[3])
sb.violinplot(data = houseNumData['SalePrice'], orient = "h", ax = axes[4])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### b) Comment if the distributions look like “Normal Distribution”, or different. Use the .skew() method to find the
# #### “skewness” of each of the five distributions. Which of the variables has the maximum number of outliers?

# %% [markdown]
# Most of the distributions look like Normal Distribution, with LotArea and SalePrice conforming the most to Normal Distribution. GarageArea is the one that looks the most different from a normal distribution.

# %%
houseNumData.skew()
# Out:
# LotArea        12.207688
# GrLivArea       1.366560
# TotalBsmtSF     1.524255
# GarageArea      0.179981
# SalePrice       1.882876
# dtype: float64

# %% [markdown]
# LotArea has the max number of outliers due to the high skew of the data.

# %% [markdown]
# #### c) Check the relationship amongst the variables using mutual correlation and the correlation heatmap. Comment
# #### which of the variables has the strongest correlation with “SalePrice”. Is this useful in predicting “SalePrice”?

# %%
display(houseNumData.corr())
# Out:
#               LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# LotArea      1.000000   0.263116     0.260833    0.180403   0.263843
# GrLivArea    0.263116   1.000000     0.454868    0.468997   0.708624
# TotalBsmtSF  0.260833   0.454868     1.000000    0.486665   0.613581
# GarageArea   0.180403   0.468997     0.486665    1.000000   0.623431
# SalePrice    0.263843   0.708624     0.613581    0.623431   1.000000

# %%
sb.heatmap(houseNumData.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# GrLivArea is the variable with the strongest correlation to SalePrice. This could provide an indication to how
# we expect SalePrice to be based on the GrLivArea value. However, high correlation does not equal to causation between
# the variables, so it only provides an indication that there might be something that links the two.

# %% [markdown]
# #### d) Check the relationship amongst the variables using mutual jointplots and an overall pairplot. Comment which of
# ####     the variables has the strongest linear relation with “SalePrice”. Is this useful in predicting “SalePrice”?

# %% [markdown]
# ##### Individual Plots

# %%
sb.jointplot(x = 'LotArea', y = 'GrLivArea', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'LotArea', y = 'TotalBsmtSF', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'LotArea', y = 'GarageArea', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'LotArea', y = 'SalePrice', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'GrLivArea', y = 'TotalBsmtSF', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'GrLivArea', y = 'GarageArea', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'GrLivArea', y = 'SalePrice', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'TotalBsmtSF', y = 'GarageArea', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'TotalBsmtSF', y = 'SalePrice', data = houseNumData, kind = 'scatter')
sb.jointplot(x = 'GarageArea', y = 'SalePrice', data = houseNumData, kind = 'scatter')

# %% [markdown]
# #### Joint Plot

# %%
sb.pairplot(data = houseNumData)

# %% [markdown]
# The correlation data and the jointolots correspond with each other, with the combinations that are more linear having higher correlation values.

# %% [markdown]
# ### Problem 2
# Analysis of Categorical Variables
# Extract the following Categorical variables from the dataset, and store as a new Pandas DataFrame.
# houseCatData = pd.DataFrame(houseData[['MSSubClass', 'Neighborhood', 'BldgType', 'OverallQual']])
#
#     a) Convert each of these variables into “category” data type (note that some are “int64”, and some are “object”).
#     b) Check the individual statistical description and visualize the distributions (catplot) of each of these variables.
#     c) One may check the relation amongst two categorical variables through the bi-variate joint heatmap of counts.
#     Use groupby() command to generate joint heatmap of counts for “OverallQual” against the other three variables.
#     Comment if this is useful in identifying the relation between “OverallQual” with the other variables.
#     d) Draw boxplots of “SalePrice” against each of these categorical variables. Notice the patterns in these boxplots.
#     Comment on which of these variables has the most influence in predicting “SalePrice”.

# %% [markdown]
# #### a) Convert each of these variables into “category” data type (note that some are “int64”, and some are “object”).

# %% [markdown]
# Import the dataframe

# %%
houseCatData = pd.DataFrame(houseData[['MSSubClass','Neighborhood','BldgType','OverallQual']])
display(houseCatData)
# Out:
#       MSSubClass Neighborhood BldgType  OverallQual
# 0             60      CollgCr     1Fam            7
# 1             20      Veenker     1Fam            6
# 2             60      CollgCr     1Fam            7
# 3             70      Crawfor     1Fam            7
# 4             60      NoRidge     1Fam            8
# ...          ...          ...      ...          ...
# 1455          60      Gilbert     1Fam            6
# 1456          20       NWAmes     1Fam            6
# 1457          70      Crawfor     1Fam            7
# 1458          20        NAmes     1Fam            5
# 1459          20      Edwards     1Fam            5
#
# [1460 rows x 4 columns]

# %% [markdown]
# Check what current DataTypes are

# %%
houseCatData.dtypes
# Out:
# MSSubClass       int64
# Neighborhood    object
# BldgType        object
# OverallQual      int64
# dtype: object

# %% [markdown]
# Perform the conversion

# %%
houseCatData = houseCatData.astype('category')

# %% [markdown]
# Verify that all columns are categorical

# %%
display(houseCatData.dtypes)
# Out:
# MSSubClass      category
# Neighborhood    category
# BldgType        category
# OverallQual     category
# dtype: object

# %% [markdown]
# #### b) Check the individual statistical description and visualize the distributions (catplot) of each of these variables.

# %%
houseCatData.describe()
# Out:
#         MSSubClass Neighborhood BldgType  OverallQual
# count         1460         1460     1460         1460
# unique          15           25        5           10
# top             20        NAmes     1Fam            5
# freq           536          225     1220          397

# %% [markdown]
# ##### Individual CatPlots

# %%
sb.catplot(data = houseCatData, y ='MSSubClass')
sb.catplot(data = houseCatData, y = 'Neighborhood')
sb.catplot(data = houseCatData, y = 'BldgType')
sb.catplot(data = houseCatData, y = 'OverallQual')

# %% [markdown]
# #### c) One may check the relation amongst two categorical variables through the bi-variate joint heatmap of counts.
# ####    Use groupby() command to generate joint heatmap of counts for “OverallQual” against the other three variables.
# ####    Comment if this is useful in identifying the relation between “OverallQual” with the other variables.

# %% [markdown]
# ##### Individual Plots

# %%
sb.heatmap(houseCatData.groupby(['OverallQual','MSSubClass']).size().unstack())
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='OverallQual'>

# %%
sb.heatmap(houseCatData.groupby(['OverallQual','Neighborhood']).size().unstack())
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='OverallQual'>

# %%
sb.heatmap(houseCatData.groupby(['OverallQual','BldgType']).size().unstack())
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='OverallQual'>

# %% [markdown]
# This is useful as it shows the distribution of the different columns compared to OverallQual

# %% [markdown]
# #### d) Draw boxplots of “SalePrice” against each of these categorical variables. Notice the patterns in these boxplots.
# ####    Comment on which of these variables has the most influence in predicting “SalePrice”.

# %% [markdown]
# ##### Only run this once, otherwise extra columns will be added to the DataFrame

# %%
houseCatData = pd.concat([houseCatData,houseNumData['SalePrice']], axis = 1)

# %% [markdown]
# ##### Verify data

# %%
display(houseCatData)
# Out:
#      MSSubClass Neighborhood BldgType OverallQual  SalePrice
# 0            60      CollgCr     1Fam           7     208500
# 1            20      Veenker     1Fam           6     181500
# 2            60      CollgCr     1Fam           7     223500
# 3            70      Crawfor     1Fam           7     140000
# 4            60      NoRidge     1Fam           8     250000
# ...         ...          ...      ...         ...        ...
# 1455         60      Gilbert     1Fam           6     175000
# 1456         20       NWAmes     1Fam           6     210000
# 1457         70      Crawfor     1Fam           7     266500
# 1458         20        NAmes     1Fam           5     142125
# 1459         20      Edwards     1Fam           5     147500
#
# [1460 rows x 5 columns]

# %% [markdown]
# ##### Individual Box Plots

# %%
sb.boxplot(x = houseNumData['SalePrice'], y = houseCatData['MSSubClass'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='MSSubClass'>

# %%
sb.boxplot(x = houseNumData['SalePrice'], y = houseCatData['Neighborhood'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Neighborhood'>

# %%
sb.boxplot(x = houseNumData['SalePrice'], y = houseCatData['BldgType'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BldgType'>

# %%
sb.boxplot(x = houseNumData['SalePrice'], y = houseCatData['OverallQual'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='OverallQual'>

# %% [markdown]
# OverallQual seems to have the biggest impact on SalePrice, with houses that have higher OverallQual
# having higher SalePrice and is the one indicator where every level steadilly increases the minimum SalePrice.

# %% [markdown]
# Doing the boxplot with the combined DataFrame gave errors. I went back to using the the default DataFrames and indexes.
